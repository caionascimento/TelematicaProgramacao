# %% [markdown]
# # <center>Coleta e análise de dados do Twitter utilizando a biblioteca Tweepy</center>
# ## <center>Caio Luna</center>
#
# ## 1. Estudo comparativo entre dois perfis de usuários

# %% [markdown]
# Com o auxílio da biblioteca Tweepy, é possível coletar amostras de Tweets e Retweets dos usuários, dados de suas contas, informações sobre as *Trends Topics* entre outras informações.
#
# Para o uso efetivo da biblioteca é necessário cadastrar sua aplicação na plataforma de desenvolvedor do Twitter (disponível **[Aqui](https://developer.twitter.com/)**) onde é necessário responder alguns questionários sobre como será utilizada e qual a finalidade do uso da API.

# %% [markdown]
# Depois que a aplicação foi efetivamente registrada, é necessário copiar quatro informações, são elas:
# * *Consumer API key*
# * *Consumer API secret key*
# * *Access token*
# * *Access token secret*
#
# Com elas, o código poderá se comunicar com a API do Twitter passando as credenciais da aplicação registrada na plataforma de desenvolvedor.

# %% [markdown]
# Abaixo estão presentes as bibliotecas importadas para a devida funcionalidade do código.

# %%
import tweepy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import re
# %matplotlib inline

# %% [markdown]
# Por segurança, é viável que cada desenvolvedor **utilize suas chaves e tokens de acessos individualmente**, sem a divulgação das mesmas para a comunidade, então para começar a estudar a biblioteca, substitua os caracteres **XXX** abaixos pelas chaves e tokens da sua aplicação que foi registrada na plataforma do Twitter.

# %%
#Autenticações para uso da API
consumer_key = 'zCojyZyS6kcCwxf2AI6Sypa7v'
consumer_secret = 'Tau6UruIn0wqJSkiGYrNYeR3MinPNIakdczqADzMrecM47SL6z'
access_token = '1139728811971530754-XegSH8RyLJx21pD0f1Op82aRlvKoS2'
access_token_secret = 'M0UWJisokWlg472cKR0OhKPkRprptAVYR83WGGZ1Xztl0'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %% [markdown]
# Agora que já importamos as bibliotecas que serão utilizadas e já possuímos acesso a API do Twitter, podemos começar a escrever o código de acordo com nossas necessidades.
#
# A função `info_usuario()` que foi criada, é utilizada para resgatar informações do usuário que é passado como parâmetro e guarda as informações em uma lista criada pra cada usuário.
# Nesta função, é chamado o metodo `get_user()` que retorna um **Objeto de Usuário** com todas as informações dísponiveis, no nosso caso, iremos utilizar algumas dessas informações, são elas:
# * Nome
# * Local
# * Descrição
# * Total de seguidores
# * Total de pessoas seguidas pelo perfil
# * Data de criação da conta
# * Total de likes dado pelo perfil
# * Verificação da conta
# * Total de Tweets e Retweets
#
# Para realizar o estudo comparativo entre duas contas, serão utilizadas as atuais contas do Twitter do atual presidente do Brasil, Jair Messias Bolsonaro e do ex-presidente, Luiz Inácio Lula da Silva.
#
# Vale resaltar que os resultados que serão encontrados abaixo podem sofrer alterações, pois estamos tratando de uma rede social muito volátil, que está em constante modificação por parte dos usuários.

# %%
#Verifica as informações dos usuários 
def info_usuario(user, lista_usuario):
    #Recupera as informações do usuário e adiciona as características solicitadas em uma lista  
    usuario = api.get_user(user)
    nome = usuario.name
    lista_usuario.append(nome)
    local = usuario.location
    lista_usuario.append(local)
    descricao = usuario.description
    lista_usuario.append(descricao)
    totalseguidores = usuario.followers_count
    lista_usuario.append(totalseguidores)
    totalseguidos = usuario.friends_count
    lista_usuario.append(totalseguidos)
    criacao = usuario.created_at
    lista_usuario.append(criacao)
    totallikes = usuario.favourites_count
    lista_usuario.append(totallikes)
    verificacao = usuario.verified
    lista_usuario.append(verificacao)
    totaltweets = usuario.statuses_count
    lista_usuario.append(totaltweets)
    print('\nNome:', nome,'\nLocal:', local,'\nDescrição:', descricao,'\nQuant. Seguidores:', totalseguidores,
          '\nQuant. Seguidos:', totalseguidos,'\nData de Criação:', criacao,'\nQuant. Likes:', totallikes,
          '\nConta Verificada:', verificacao, '\nQuant. Tweets:', totaltweets)
    
#Chama a função com o usuários passando como parâmetro o nome da conta e uma lista para guardar as informações 
lista_bolsonaro = []
info_usuario('jairbolsonaro', lista_bolsonaro)
lista_lula = []
info_usuario('LulaOficial', lista_lula)
# Out:
# Nome: Jair M. Bolsonaro
# Local: Brasília, Brazil
# Descrição: Capitão do Exército Brasileiro, eleito 38° Presidente da República Federativa do Brasil. 🇧🇷
# Quant. Seguidores: 4610546
# Quant. Seguidos: 345
# Data de Criação: 2010-03-31 23:13:44
# Quant. Likes: 2036
# Conta Verificada: True
# Quant. Tweets: 7088
#
# Nome: Lula
# Local:
# Descrição: Ex-presidente da República do Brasil (2003-2010). Preso político desde 7 de abril de 2018.
# Quant. Seguidores: 875818
# Quant. Seguidos: 623
# Data de Criação: 2014-07-22 21:36:50
# Quant. Likes: 2613
# Conta Verificada: True
# Quant. Tweets: 18544

# %% [markdown]
# ---
# Também podemos verificar quantos e quais são os perfis que os dois usuários seguem e quantos perfis seguem os dois usuários simultaneamente, na função `info_usuario_amizade_comum()` e na `info_usuario_seguidores_comum()` que foram criadas abaixo, passamos como parâmetro os dois usuários para encontrar quais os perfis que tem os dois usuários como seus seguidores e a quantidade de perfis que seguem os dois, respectivamente.
#
# Na primeira função `info_usuario_amizade_comum()` com auxílio do método `friends_ids()` que retorna uma **Lista de Inteiros** com os IDs (identificadores únicos de cada perfil) que o usuários seguem, é possível verificar quais os perfis os dois seguem simultaneamente com a utilização de dois laços simples e chamamos novamente a função anteriormente citada `info_usuario()` para uma amostra mais detalhada sobre esses perfis.

# %%
#Verifica os perfis que os dois usuários seguem "Amigos em Comuns"
print('Informações sobre os perfis que os dois usuários seguem:')
def info_usuario_amizade_comum(user1, user2):
    lista_amigos = []
    amizade_comum = 0
    seguidos_user1 = api.friends_ids(user1)
    seguidos_user2 = api.friends_ids(user2)
    for i in seguidos_user1:
        for ii in seguidos_user2:
            if i == ii:
                amizade_comum += 1
                info_usuario(i, lista_amigos)

#Chama a função passando os dois usuários como parâmetro para comparação
info_usuario_amizade_comum('jairbolsonaro', 'LulaOficial')
# Out:
# Informações sobre os perfis que os dois usuários seguem:
#
# Nome: Lenín Moreno
# Local: Ecuador
# Descrição: Esposo, padre, abuelo y Presidente Constitucional de la República del Ecuador🇪🇨, con la certeza de que el poder es un ejercicio de humildad. #ElGobiernoDeTodos
# Quant. Seguidores: 705970
# Quant. Seguidos: 38
# Data de Criação: 2012-10-29 19:54:52
# Quant. Likes: 131
# Conta Verificada: True
# Quant. Tweets: 2735
#
# Nome: Câmara dos Deputados
# Local: Brasília, Brasil
# Descrição: Perfil oficial da Câmara dos Deputados com notícias sobre votações e debates.
# Quant. Seguidores: 798370
# Quant. Seguidos: 512
# Data de Criação: 2009-07-31 18:44:16
# Quant. Likes: 1772
# Conta Verificada: True
# Quant. Tweets: 17332
#
# Nome: teleSUR TV
# Local: Caracas
# Descrição: Con más 40 corresponsales en el mundo, alzamos nuestra voz donde otros medios callan.
# teleSUR es la señal informativa de América Latina
# Quant. Seguidores: 1682134
# Quant. Seguidos: 287
# Data de Criação: 2009-06-05 22:21:49
# Quant. Likes: 916
# Conta Verificada: True
# Quant. Tweets: 1166526
#
# Nome: G1
# Local: Brasil
# Descrição: O portal de notícias da Globo
# Quant. Seguidores: 10345014
# Quant. Seguidos: 105
# Data de Criação: 2007-09-11 04:05:49
# Quant. Likes: 6
# Conta Verificada: True
# Quant. Tweets: 655940
#
# Nome: Jornal O Globo
# Local:
# Descrição: Acompanhe as notícias do jornal O GLOBO pelas nossas newsletter
# Quant. Seguidores: 5919044
# Quant. Seguidos: 7941
# Data de Criação: 2009-07-06 21:36:53
# Quant. Likes: 119
# Conta Verificada: True
# Quant. Tweets: 341748
#
# Nome: Estadão
# Local: São Paulo
# Descrição: A versão on-line do jornal O Estado de S.Paulo. Acompanhe também as atualizações pelo Facebook: http://t.co/HTvjzavEtw
# Quant. Seguidores: 6380240
# Quant. Seguidos: 62346
# Data de Criação: 2007-10-08 22:08:22
# Quant. Likes: 28
# Conta Verificada: True
# Quant. Tweets: 324110
#
# Nome: Correio Braziliense
# Local: Brasília, Brasil
# Descrição: Você à frente de tudo
# Quant. Seguidores: 697055
# Quant. Seguidos: 51
# Data de Criação: 2009-08-19 22:57:39
# Quant. Likes: 264
# Conta Verificada: True
# Quant. Tweets: 320244

# %% [markdown]
# ---
# Já na segunda função `info_usuario_seguidores_comum()` é utilizada o método `followers_ids()` que também retorna uma **Lista de Inteiros** com os IDs dos seguidores do usuário, também utilizando dois laços simples, encontramos a quantidade de perfis que seguem os dois simultaneamente.

# %%
#Verifica quantos seguidores seguem os dois usuarios simultaneamente
def info_usuario_seguidores_comum(user1, user2):
    seguidores_comum = 0
    seguidores_user1 = api.followers_ids(user1)
    seguidores_user2 = api.followers_ids(user2)
    for i in seguidores_user1:
        for ii in seguidores_user2:
            if i == ii:
                seguidores_comum += 1
    print('\nDos', lista_bolsonaro[3], 'perfis que seguem o', lista_bolsonaro[0], 
          'e dos', lista_lula[3], 'perfis que seguem o', lista_lula[0], 'apenas', 
          seguidores_comum, 'perfis seguem os dois usuários simultaneamente!')
#Chama a função passando os dois usuários como parâmetro para comparação
info_usuario_seguidores_comum('jairbolsonaro', 'LulaOficial')
# Out:
# Dos 4610546 perfis que seguem o Jair M. Bolsonaro e dos 875818 perfis que seguem o Lula apenas 94 perfis seguem os dois usuários simultaneamente!

# %% [markdown]
# ## 2. Plotagem de Gráficos
#
# Com as informações dos dois usuários que resgatamos anteriormente, podemos começar a iniciar a plotagem de alguns gráficos.
# Nos exemplos abaixo foi criado alguns Data Frame com as informações necessárias para plotar o gráfico.
#
# Os valores sobre a quantidade de seguidores foram extraídos pela função `info_usuario()` são passados para uma lista chamada `data` que é utilizada como parâmetro da função `informa_valor()`, ela foi criada para ser passada nas características do grafico `autopct` no método `plot.pie`, com a função `informa_valor()`, é calculada o tamanho de cada fatia da pizza para os dois usuários e retorna o valor dos seguidores que os dois perfis possuem.

# %%
#Criando um DataFrame para uso do gráfico
df = pd.DataFrame({'Quant. Seguidores': [lista_bolsonaro[3], lista_lula[3]]})
data = [lista_bolsonaro[3], lista_lula[3]]
def informa_valor(pct, valores):
    absolute = int(pct/100.*np.sum(valores))
    return "{:.1f}%\n({:d})".format(pct, absolute)

#Plotando o gráfico de pizza
df.plot.pie(y='Quant. Seguidores', explode=(0,0.1), labels = ['Bolsonaro', 'Lula'], title='Seguidores', 
            figsize=(10, 5), colors=['green', 'red'], shadow=True, autopct=lambda pct: informa_valor(pct, data))

# %% [markdown]
# ---
# O modelo de gráfico gerado foi em forma de pizza, nele podemos observar a quantidade de seguidores que cada usuário tem. É possível observar que há uma grande superioridade na quantidade de seguidores em um dos perfis comparados, onde no total de seguidores dos dois, aproximadamente **84.0%** seguem o atual presidente do Brasil e **16.0%** seguem o ex-presidente.
#
# O gráfico a seguir utiliza da mesma ideia do discutido anteriormente, porém aqui iremos analisar a quantidade de tweets e retweets dos dois perfis desde a data da sua criação.

# %%
#Criando um DataFrame para uso do gráfico
df = pd.DataFrame({'Quant. Tweets': [lista_bolsonaro[8], lista_lula[8]]})
data = [lista_bolsonaro[8], lista_lula[8]]
def informa_valor(pct, valores):
    absolute = int(pct/100.*np.sum(valores))
    return "{:.1f}%\n({:d})".format(pct, absolute)

#Plotando o gráfico de pizza
df.plot.pie(y='Quant. Tweets', explode=(0,0.1), labels = ['Bolsonaro', 'Lula'], title='Tweets', 
            figsize=(10, 5), colors=['green', 'red'], shadow=True, autopct=lambda pct: informa_valor(pct, data))

# %% [markdown]
# ---
# No novo gráfico gerado, é possível ver uma maior “movimentação” no perfil do ex-presidente, onde possui mais de **70.0%** do total de tweets e retweets dos dois perfis.
#
# Vale salientar que a data da criação do perfil do atual presidente foi no dia **31/03/2010** e a do ex-presidente foi em **22/07/2014** (segundo resultado da função `infor_usuario()`), ou seja, o perfil do ex-presidente é pouco mais de **quatro anos mais novo** que o perfil do atual presidente, mas mesmo assim, ele utilizou os tweets e retweets em uma quantidade bem maior. Esse fato indica que há uma utilização mais assídua da rede social por parte do perfil do ex-presidente.
#
# O próximo gráfico faz uma relação direta na quantidade dos Perfis Seguidos e os Likes dos dois perfis utilizando o metodo `plot.bar()`.

# %%
#Criando um DataFrame para uso do gráfico
df = pd.DataFrame({'Bolsonaro': [lista_bolsonaro[4], lista_bolsonaro[6]], 'Lula': [lista_lula[4], lista_lula[6]]}, 
                 index=['Perfis Seguidos', 'Likes'])

#Plotando o gráfico de barras
df.plot.bar(rot=0, color=['green','red'], grid=True, title='Relação de Perfis Seguidos e Likes', figsize=(10, 5))

# %% [markdown]
# ---
# Com o gráfico de barras gerado, é possível constatar que a o perfil do ex-presidente segue um quantidade maior de perfis e utiliza mais o botão de *like*, fato este que é mais um indício que o perfil do ex-presidente realiza mais interações na rede social em comparação ao perfil do atual presidente.
#
# ## 3. Extração de Tweets
#
# Para realizar mais algumas análises, também podemos recuperar uma quantidade de Tweets e Retweets dos dois perfis analisados. Para isto, iremos utilizar o método `user_timeline()` que retorna uma **Lista de Objetos** do tipo **Status**.
#
# Dentro da função `extrair_tweets()` há um laço para separar apenas as informações que desejamos, no caso, no método `sub()` é separada a *url* do tweet (que no momento não nos interessa) e pega apenas o texto do Tweet ou do Retweet.

# %%
#Verifica e guarda em uma lista os Tweets e os Retweets dos usuários
def extrair_tweets(nome_usuario, inclui_retweet=True):
    resultados = api.user_timeline(screen_name=nome_usuario, count=200, 
                                   tweet_mode='extended', include_rts=inclui_retweet)
    tweets = []
    for s in resultados:
        tweet = re.sub(r'http\S+', '', s.full_text)
        tweets.append(tweet.replace('\n', ' '))
    return tweets

# %% [markdown]
# Ao chamar a função `extrair_tweets()` é necessário passar como parâmetro o nome do usuário que você deseja coletar os Tweets e outro parâmetro *booleano* onde:
# * *True* indica que a função retornará Tweets e Retweets
# * *False* indica que a função retornará apenas Tweets
#
# O método `user_timeline()` possui uma limitação na recuperação dos tweets de no máximo 200, dísponivel **[Aqui](https://developer.twitter.com/en/docs/tweets/timelines/api-reference/get-statuses-user_timeline.html)** para mais informações sobre.

# %%
#Chama a função passando como parâmetro o usuário e se a pesquisa vai incluir os Retweets ou não
tweets_bolsonaro = extrair_tweets('jairbolsonaro', True)
for i in tweets_bolsonaro:
    print('\n', i)
# Out:
#  - A aplicação acontecerá de maneira gradual, mas já em 2020 será feita uma aplicação piloto. Estamos aplicando sistemas já testados em outros países. O Brasil tem, sim, tecnologia e segurança para desempenhar atividades desse porte.
#
#  - O Ministro da Educação, @AbrahamWeint, apresentou, em audiência no MEC, a proposta do Enem Digital. A ideia é tornar o Enem acessível a mais municípios, diminuir a burocracia, reduzir os gastos e transformar a prova em um modelo sustentável, com menos impressão de papel.
#
#  @Jrodrigues1954 @feitosamaria - Valeu José. 👍
#
#  @feitosamaria - Pra você também, Maria. 👍🇧🇷
#
#  @JoinhaSempre 👍
#
#  @GinPiero2 Limeira 👍
#
#  - DECOLANDO: ANAC autorizou mais uma empresa aérea de baixo custo para operar voos internacionais no Brasil. A companhia realizará viagens entre Buenos Aires e RJ. Seguimos avançando, abrindo nosso mercado para levar aos brasileiros melhores ofertas e serviços de qualidade. 🇧🇷👍
#
#  - Fica calmo. Um forte abraço!
#
#  - Final: Brasil 2 x 0 Argentina. Obrigado, Belo Horizonte! Boa noite a todos! 🇧🇷🇧🇷🇧🇷
#
#  - Intervalo de jogo. BRASIL 1 X 0 ARGENTINA. 🇧🇷🇧🇷🇧🇷
#
#  - Agora no Mineirão com @neymarjr. Boa sorte, Brasil! 🇧🇷
#
#  Nos últimos dias foram iniciadas as obras de pavimentação da Transamazônica (BR-230/PA - trecho entre Marabá e Divisa de Tocantins). Além da pavimentação, pontes de madeira estão sendo substituídas por estruturas de concreto. É o nosso @MInfraestrutura sem tempo para descanso. 🇧🇷
#
#  - Obrigado pela homenagem anime! Nota 10! 👍
#
#
#
#  - Oyasuminasai - おやすみなさい - (Boa noite!)
#
#  - Apesar de o prazo para apreciação no Congresso da MP que trata do fim da cobrança obrigatória do imposto sindical a empregados ter se encerrado na última quinta (27), o STF decidiu liminarmente suspender a cobrança do imposto sem autorização do funcionário. Ótima notícia!
#
#  - @CarlosBolsonaro 👍🇧🇷
#
#  Parabéns a todos que foram às ruas nesse 30/06. A mensagem de vocês é p/ TODAS as autoridades: "não parem o Brasil, combatam a corrupção, apoiem quem foi legitimamente eleito em 2018." Respeito todas as Instituições, mas acima delas está o povo, meu patrão, a quem devo lealdade.
#
#  - Aos que foram às ruas hoje manifestar seus anseios, parabéns mais uma vez pela civilidade. A população brasileira mostrou novamente que tem legitimidade, consciência e responsabilidade para estar incluída cada vez mais nas decisões políticas do nosso Brasil. 🇧🇷👍
#
#  RT @ernestofaraujo: Durante 20 anos o Brasil tentou chegar lá sendo um aluno aplicado na escola do globalismo. Não deu. O Brasil que agora…
#
#  Retorno agora de Osaka. G 20, MISSÃO CUMPRIDA! Parabéns BRASIL! 🇧🇷🇧🇷🇧🇷
#
#  - Parabéns Ministro @Astro_Pontes e equipe!
#
#  - No acordo União Européia/MERCOSUL o Brasil manteve todas as conquistas da Lei da Inovação, as encomendas tecnológicas, as compras de pequenas e micro empresas e, sobretudo, a previsão que permite a exigência de transferência de tecnologia nos contratos internacionais.
#
#  Já está disponível em nosso canal no Youtube a íntegra da Live Semanal realizada na última quinta-feira, diretamente do Japão. Confira:
#
#  - Em minha 1a conversa com o PM de Singapura, Lee Hsien Loong, ficou claro que queremos fazer muito mais nas relações entre nossos países. Singapura é um grande investidor no Brasil e quer investir ainda mais. Estou otimista com as perspectivas de celebrarmos um acordo comercial.
#
#  - Antes de concluir missão em Osaka, estive com o PM do Japão, Shinzo Abe. Na pauta, ações conjuntas para ampliar comércio e investimentos, bem como para promover pesquisa e uso do nióbio e grafeno. A base da sólida parceria nipo-brasileira só tende a se fortalecer cada vez mais.
#
#  Firme em minha determinação de trazer investimentos para nosso país, conversei com o Príncipe Mohammad bin Salman da Arábia Saudita, maior economia do mundo árabe, sobre oportunidades de investimento no Brasil. Estamos adotando uma posição muito mais equilibrada no Oriente Médio.
#
#  Minha reunião com o PM da Índia, @narendramodi, foi excelente. Nossos países são grandes amigos e têm grandes semelhanças. Concordamos em aprofundar nossa cooperação com uma perspectiva de longo prazo e em áreas que fomentam o desenvolvimento, como agricultura e biocombustíveis.
#
#  Celebrando com o Presidente da Argentina, @mauriciomacri, o acordo histórico que fechamos hoje com a União Européia. Nossa parceria tem enorme potencial e ainda dará muita alegria aos nossos povos. 🇧🇷🤝🇦🇷
#
#  RT @MagarinosC: Obrigado por sua liderança Presidente @jairbolsonaro Parabéns para ministros e legisladores que empurraram as negociações @…
#
#
#
#  - Presidente Bolsonaro encontra Presidente Trump em Osaka, Japão. 🇯🇵🇧🇷🇺🇸  Via: @emb_resistencia
#
#  - Tereza Cristina e Ernesto negociando em Bruxelas, Onyx e Guedes no Brasil e eu, após conversar com Merkel, Macron e Macri em Osaka, fechamos o acordo do Mercosul com a União Européia. Depois de 20 anos, e sem mais o viés ideológico, a vitória. Parabéns BRASIL! 🇧🇷
#
#  素晴らしい日 👍
#
#  - Prometi que faria comércio com todo o mundo, sem viés ideológico.  Não foi retórica vazia de campanha, típica da velha política. É pra valer! Estou cumprindo mais essa promessa, que renderá frutos num futuro próximo. Vamos abrir nossa economia e mudar o Brasil pra melhor! 🇧🇷
#
#  Juntos, Mercosul e UE representam 1/4 da economia mundial e agora os produtores brasileiros terão acesso a esse enorme mercado. Parabenizo também os Ministros Paulo Guedes e Tereza Cristina, bem como as equipes de seus ministérios, pelo empenho neste objetivo. GRANDE DIA! 👍
#
#  Histórico! Nossa equipe, liderada pelo Embaixador Ernesto Araújo, acaba de fechar o Acordo Mercosul-UE, que vinha sendo negociado sem sucesso desde 1999. Esse será um dos acordos comerciais mais importantes de todos os tempos e trará benefícios enormes para nossa economia.
#
#  Na reunião com o Presidente @realDonaldTrump, retomamos assuntos tratados na visita a Washington e introduzimos a idéia de um acordo de livre comércio para fortalecer ainda mais nossa parceria econômica. Trabalhando juntos, Brasil e EUA podem ter impacto muito positivo no mundo.
#
#  - @realDonaldTrump 👍
#
#  Em primeiro encontro com o Presidente da Espanha, Pedro Sánchez, aproveitei para agradecê-lo pelo modo como as autoridades espanholas estão lidando com o caso dos entorpecentes apreendidos em avião da FAB e reafirmei minha defesa por punição severa para o tráfico.
#
#  - Reunião informal do BRICS.
#
#  - Há pouco, com o novo Presidente do Banco Mundial, David Malpass. Discutimos as perspectivas da já sólida parceria entre o Brasil e o Banco. Nosso Governo tem interesse em seu apoio ao setor produtivo e em maior atuação sua no financiamento de infraestrutura no Brasil.
#
#  Audiência com Secretário-Geral da OCDE, Sr. José Ángel Gurría Treviño. Conversamos sobre os próximos passos para uma relação ainda mais forte com a organização. Gurría mostrou grande entusiasmo com nossa agenda de reformas. 🇧🇷👍
#
#  Perderam porque colocaram um preso condenado por corrupção em suas campanhas, e o povo brasileiro não gosta de bandido. Nós vencemos e estamos consertando todos esses erros!
#
#  Deveriam se conformar. Perderam porque roubaram, quebraram o país e o entregaram ao desemprego e à violência generalizada; porque estavam transformando o Brasil em uma Venezuela; porque defendem aborto, desencarceramento, controle da internet e da mídia e outros absurdos.
#
#  A oposição tenta a todo custo emplacar a tese de que só perdeu as eleições por conta de supostas fake news, como se a população brasileira fosse idiota e eles tivessem muita credibilidade.
#
#  No próximo 02/julho a Caixa Econômica Federal lança, na Câmara dos Deputados, uma linha de crédito para hospitais filantrópicos com recursos do FGTS. Atenderemos, assim, antigo pleito das Santas Casas, num volume quatro vezes maior que o do BNDES para o mesmo fim.
#
#  - Depois de 27 horas de viagem chegamos ao Japão. Nesta quinta-feira, às 19hs, nossa live, diretamente de Osaka.
#
#  - Agora, última escala antes do Japão. Aeroporto Nursultan Nazarbayev, Cazaquistão.
#
#  Apesar de não ter relação com minha equipe, o episódio de ontem, ocorrido na Espanha, é inaceitável. Exigi investigação imediata e punição severa ao responsável pelo material entorpecente encontrado no avião da FAB. Não toleraremos tamanho desrespeito ao nosso país!
#
#  - Escala em Portugal, rumo ao Japão. Base Aérea Figo Maduro.
#
#  - O Brasil levará para a cúpula uma mensagem de abertura e de apoio à liberdade econômica. Marcaremos nossa posição em favor do sistema multilateral de comércio e apresentaremos, aos demais participantes, nossa agenda de reformas para reerguer a economia do nosso país. 🇧🇷
#
#  - Embarco, daqui a pouco, rumo a Osaka, no Japão, onde participarei da cúpula do G20, o grupo das 20 maiores economias. Trataremos das perspectivas para o comércio e os investimentos e de grandes temas da agenda mundial, como inovação, infraestrutura e novas matrizes energéticas.
#
#  @WillameFerrei15 👍
#
#  Hoje a CGU, AGU, MPF e Departamento de Justiça dos Estados Unidos assinaram mais um acordo: R$ 273 milhões pagos este mês e mais duas prestações de igual valor a serem pagos em 2020 e 2021. Tudo referente aos desvios praticados na Petrobrás.
#
#  🇧🇷
#
#
#
#  RT @AbrahamWeint: Firmamos, hoje, o Procad-Defesa para estimular projetos conjuntos com o @DefesaGovBr e a @CAPES_Oficial voltados à pesqui…
#
#  Na Lei 13.846/19 (Combate à Fraude), os cartórios devem informar a relação de óbitos até 24 horas após seu registro. Antes esse prazo era de 40 dias, onde, pelo lapso de tempo, o falecido tinha depositado em sua conta mais 2 salários. Economia prevista será de R$ 1,7 bilhão/ano.
#
#  - Nesta manhã recebi da PM do Distrito Federal sua mais alta honraria, a Medalha Tiradentes. Na oportunidade cumprimento os policiais militares de todo o Brasil.
#
#  - Não fomos felizes no placar, mas vitoriosos na garra, determinação e honra à camisa verde-amarela. Às meninas do futebol os nossos cumprimentos por bem representar o Brasil no Mundial Feminino da França. 🇧🇷
#
#  Obrigado a todos pela ajuda! 👍
#
#  - Boas notícias para o campo, mas reconhecemos que os juros ainda estão altos no Brasil.
#
#  RT @exercitooficial: Nesse sabadão, nossos combatentes não deram descanso à pavimentadora para acelerar os trabalhos na BR-163 @Engenharia…
#
#  - O Brasil voltando aos *TRILHOS*. - Lote 5, Ferrovia da Integração Oeste-Leste.
#
#  @DadsDaughter777 @tavinhopg_ @AmorAoJairB Muito obrigado pelo apoio! Um abraço!
#
#  @marianatomadon @tavinhopg_ 👍🇧🇷
#
#  @OliverlivVictor 👍
#
#  @JOAQUINTEIXElRA Kkkkkk! 👍
#
#  @tavinhopg_ Forte abraço! 👍
#
#  @TVMaresol Abraço aos fãs de Winning Eleven 👍
#
#  @PATRlOTAS 👍
#
#  Boa noite a todos!
#
#  - Marginais que executaram o Sgt da PMAM Luís Carlos da Silva Castro, com 10 tiros, sendo 8 nas costas, saem pela porta da frente da delegacia após serem ouvidos em *Audiência de Custódia*. Em 2016 @bolsonarosp apresentou PDC p/ sustar a Resolução do CNJ que criou as Audiências.
#
#  - DNIT no Vale do Jequitinhonha. Recapeamento da Rodovia 367 e alargamento sobre a ponte do Rio Araçuaí. Nossos parabéns ao Capitão Tarcísio, Ministro da Infraestrutura!
#
#  RT @SF_Moro: Parabéns à Receita Federal. Ainda bem que o Congresso rejeitou a proposta de proibi-la de atuar somente em crimes tributários.…
#
#  Anuncio o Advogado e Major PMDF Jorge Antonio de Oliveira Francisco p/ o cargo de Ministro-chefe da Secretaria Geral PR. Outrossim, informo que o General Floriano Peixoto, que segue gozando de nossa total confiança em seu trabalho e dedicação, assumirá a Presidência dos Correios.
#
#  - Hoje, na Marcha para Jesus em São Paulo. Pela primeira vez um Presidente da República participa do evento. Boa noite a todos! 🇧🇷
#
#
#
#  09/12/2004.
#
#  @netobegalli Fãs de Dragon ball 👍
#
#  Daqui a pouco, às 19 horas, trataremos de assuntos relevantes na nossa live da semana, transmitida em nossa página oficial no Facebook. Até já! 👍
#
#  - Neste feriado, ao lado da minha Mãe, em Eldorado Paulista/SP. - com @BolsonaroSP
#
#  - Chegada em Eldorado Paulista/SP.
#
#  Feliz Corpus Christi! Registro de ontem em visita ao Mosteiro das Irmãs Clarissas, na Fazenda Nova Esperança, em Guaratinguetá/São Paulo, que também funciona como local de tratamento de dependentes químicos.
#
#  Além de agilizar a venda de bens apreendidos do tráfico de drogas e o uso desses recursos para o combate ao mesmo, a MP assinada nesta segunda também prevê a contratação temporária de engenheiros pelo @JusticaGovBR para elaboração de projetos de construção e reforma de presídios.
#
#  Guerreiros da Polícia do Exército. - com @BolsonaroSP
#
#  - Juntamente com alunos de Educação Física da PM de São Paulo, convidei o Governador a pagar 10 flexões.
#
#  - Aproveito para anunciar que na próxima semana, irei à Osaka, no Japão, onde participarei da reunião do G20 e de reunião privada com o Primeiro-Ministro japonês, Shinzo Abe.
#
#  - Em 18 de Junho de 1908, imigrantes japoneses pioneiros desembarcaram do navio Kasato Maru em terras brasileiras. Hoje, celebramos a imensa contribuição cultural, econômica e tecnológica que a comunidade nipo-brasileira tem dado ao nosso país desde então.
#
#  Quem deixa de ter acesso a armas de fogo com leis de desarmamento, o cidadão que quer apenas se proteger ou o criminoso, que, por definição, não segue as leis? O direito à legítima defesa não pode continuar sendo violado! Nem todo mundo possui condição de ter seguranças armados.
#
#  - Por 47 a 28, o Senado derrota nosso Decreto sobre CACs e Posse de Armas de Fogo. Esperamos que a Câmara não siga o Senado, mantendo a validade do nosso Decreto, respeitando o Referendo de 2005 e o legítimo direito à defesa.
#
#  - Sancionei há pouco a agora Lei que combate as fraudes previdenciárias no INSS, originária da MP 871. Serão aproximadamente R$ 9,8 bilhões economizados já nos próximos 12 meses. Avanço mais que importante para o Brasil! 🇧🇷
#
#  RT @CarlosNadalim: Olá, pessoal! Aqui é o Carlos Nadalim, Secretário de Alfabetização do @MEC_Comunicacao. A partir de hoje estarei com voc…
#
#  - O chocante caso do menino Ruan, que teve seu órgão genital decepado e foi esquartejado pela própria mãe e sua parceira, é um dos muitos crimes cruéis que ocorrem no Brasil e que nos faz pensar que infelizmente nossa constituição não permite prisão perpétua.
#
#  RT @SF_Moro: Entrevista no Ratinho, hoje à noite.
#
#  - Comunico a indicação do economista Gustavo Montezano para a Presidência do Banco Nacional do Desenvolvimento (BNDES).
#
#  - O povo deve ter o direito às armas para se defender daqueles que ousem tirar a sua liberdade.
#
#  @10Ronaldinho 🤙
#
#  @10Ronaldinho 🤙
#
#  Hoje recebi a visita do craque @10Ronaldinho. 🇧🇷👍
#
#  - Hoje, 17 de junho, assinaremos Medida Provisória que simplifica e desburocratiza a venda e utilização de bens apreendidos do tráfico em políticas de prevenção e combate ao crime organizado. De maneira inteligente, vamos combater o crime com os recursos do crime.
#
#  -  Avaliaremos também a possibilidade de reduzir impostos para jogos eletrônicos. 👍
#
#  - Para estimular a competitividade e inovação tecnológica, o governo estuda, via secretaria do Ministério da Economia, a possibilidade de reduzir de 16% para 4% os impostos sobre importação de produtos de tecnologia da informação, como computadores e celulares.
#
#  Marchando na Cerimônia comemorativa ao 218º aniversário de nascimento do Marechal Emilio Luiz Mallet, patrono da arma de artilharia do Exército Brasileiro, em Santa Maria/RS.
#
#  - Agora em Santa Maria. Obrigado Rio Grande do Sul!
#
#  Bom sábado a todos!
#
#  A CCJ do Senado decidiu revogar nossos decretos sobre CACs e posse de armas de fogo. Na terça (18), o PL será votado no plenário. Caso aprovado, perdem os CACs e os bons cidadãos, que dificilmente terão direito de comprar legalmente suas armas. Cobrem os senadores do seu Estado.
#
#  - Morumbi, agora. - Brasil 2x0 Bolívia
#
#  Recebendo os alunos do Colégio Villa Galileu, de Anápolis, no Palácio do Planalto. A essas crianças pertence o futuro do nosso Brasil! 🇧🇷
#
#  Ontem (13) o Conselho Nacional de Trânsito, presidido pelo o Min. da Infraestrutura, @tarcisiogdf, decidiu acabar com a obrigatoriedade do uso de simuladores para tirar habilitação. O custo da CNH será reduzido em aproximadamente R$ 300 reais. Mais uma promessa sendo cumprida! 👍
#
#  Assista Live da Semana com Presidente Jair Bolsonaro - 13 de Junho de 2019:
#
#  Chegada em Belém/PA. 🇧🇷
#
#  Os hospitais filantrópicos vão contar com nova linha de crédito de R$ 1 bilhão lançada hoje (13). Resultado de parceria entre o BNDES e o Ministério da Saúde, destina financiamentos a instituições sem fins lucrativos que prestam atendimentos a usuários do SUS. 👍 via: @planalto
#
#  Com muita emoção, recebi a visita do Chefe da Equipe Médica que salvou minha vida na Santa Casa de Juiz de Fora/MG. Ao Dr. Paulo Gonçalves de Oliveira Júnior e equipe, meu eterno agradecimento.
#
#  O @MinEconomia anunciou devolução de R$ 3 bilhões da Caixa Econômica Federal ao Tesouro Nacional, que será usado para aliviar a dívida pública. Outros bancos que devem ao Tesouro, como BNDES e Banco do Brasil, deverão seguir o mesmo caminho. Estamos fazendo nosso dever de casa!
#
#
#
#  Totalizam 287 as atividades consideradas de baixo risco, entre elas cabeleireiro, psicologia, manicure, serviços de borracharia, ensino de dança, música e idiomas, agências de notícias, bares e outros. Estamos tirando o peso do estado das costas de quem quer produzir.
#
#  Publicada a Resolução n° 51 da MP da Liberdade ecomômica, que traz a lista de atividades que passam a ser consideradas de baixo risco e dispensam autorização prévia do Poder Público, como por exemplo alvarás.
#
#  RT @governodobrasil: Com a #novaprevidência, quem ganha um salário mínimo vai pagar menos do que paga atualmente. Essa é a verdade! Tem dúv…
#
#  - 12 de Junho. Estádio Mané Garrincha, Flamengo x CSA.
#
#  Feliz dia dos namorados! 👍
#
#  "Quem deve conduzir o destino da nação são os senhores, o povo. Vocês que têm que dar um norte para nós. Nossa obrigação é não atrapalhá-los." 🇧🇷
#
#  Presidente Jair Bolsonaro fala para líderanças empresariais na FIESP - 11 de Junho de 2019:
#
#  @fernandatanaka_ Feliz aniversário e felicidades! Um forte abraço!
#
#  @lucaselias20 @flaviogarage Abraço e melhoras. (kkkkk)
#
#  @ClaudioMacielpf 👍
#
#  @TheRhu4n Iguatemi-MS 👍
#
#  @flaviogarage Forte abraço para os mecânicos do Brasil 👍
#
#  Juntos, estamos mudando o Brasil! Boa noite a todos! 🇧🇷
#
#  - O advogado de Adélio Bispo diz que o mandante do atentado contra Jair Bolsonaro é quem paga seus honorários.
#
#  Por 450 x 0 votos na Câmara e 61 x 0 no Senado, O PLN 4 ESTÁ APROVADO! Com isso, poderemos garantir o pagamento de benefícios aos mais necessitados, como idosos com deficiência, BPC e Bolsa Família. Parabenizo o Congresso pela consciência e responsabilidade nesta aprovação! 👍🇧🇷
#
#  - Depois de mais de 30 anos, o Exército concluirá o asfaltamento da BR 163. 🇧🇷
#
#  Hoje - 11 de Junho - a Petrobrás anuncia a segunda redução no preço do litro da gasolina nas refinarias, passando de R$ 1,81 para R$ 1,75.
#
#  Jair Bolsonaro - 20 anos do Ministério da Defesa: A verdade acima de tudo:
#
#  - 10 de junho, Dia da Artilharia. Vídeo de 2017, 9° GAC, Nioaque/MS. 🇧🇷👍
#
#  RT @BolsonaroSP: O que é o PLN 4? Por que aposentados, beneficiários do bolsa família, idosos que recebem BPC/LOAS correm risco e o preside…
#
#  MODERNIZAÇÃO DO ESTADO: Atingimos a meta de 100 serviços digitalizados no primeiro semestre. Mais de 5 milhões de solicitações deixarão de ser feitas no balcão, com uma economia de R$ 420 milhões por ano para os brasileiros. Mais em:
#
#  RT @tarcisiogdf: O trecho da BR 020/CE de Canindé até a divisa com o Piauí era um dos pontos mais críticos da malha rodoviária federal no C…
#
#  @MichelhCAM 👍
#
#  @JooFelipeM Gamers do Brasil um forte abraço! 👍
#
#  - A oposição está trabalhando para inviabilizar o pagamento de beneficiários do Bolsa Família, idosos com deficiência, Plano Safra e PRONAF. Para alcançar seus objetivos vale até prejudicar os mais pobres. Na imagem, o Vice-líder do PT:
#
#  RT @RenovaMidia: Caso o Congresso não aprove o projeto que libera crédito extra de R$ 248,9 bilhões ao governo, o presidente Jair Bolsonaro…
#
#  - O Brasil de hoje investindo em ferrovias.
#
#  - Acredito na costumeira responsabilidade e patriotismo dos deputados e senadores na aprovação urgente da matéria. 👍
#
#  - Sem aprovação do PLN 4 pelo Congresso teremos que suspender o pagamento de benefícios a idosos e pessoas com deficiência já no próximo dia 25. Nos meses seguintes faltarão recursos para aposentadorias, Bolsa Família, PRONAF, Plano Safra...
#
#  Nesta semana, sancionei lei que autoriza a internação compulsória de dependentes químicos, podendo ser solicitada pela família ou responsável legal. Por vezes, esse é o último recurso possível para impedir um mal ainda maior. O dependente não é livre, é um escravo da droga. 👍🏻
#
#  Serviços melhores e mais baratos só podem existir com menos Estado e mais concorrência, via iniciativa privada. Entre as estatais, a privatização dos Correios ganha força em nosso Governo.
#
#  - 07/JUNHO: formatura de Sargentos no Centro de Instrução Almirante Alexandrino. Parabéns a todos! O Brasil precisa de vocês! 🇧🇷
#
#  - Nossa despedida da Argentina e o sonho do peso/real.
#
#  - Encerramos nossa visita à Buenos Aires com avanços concretos e a certeza de que os laços entre Brasil e Argentina saem fortalecidos. Nossos países estão dispostos a cooperar cada vez mais em prol da liberdade e da democracia em nosso continente. Até a próxima, hermanos! 🇧🇷🤝🇦🇷
#
#  - Resumo de nossa missão no dia de ontem, 06/06, em Buenos Aires, Argentina. Bom dia a todos! 🇧🇷
#
#  RT @SF_Moro: Governo Federal, Mjsp, Governo de Roraima, um presídio outrora vergonhoso transformado.
#
#  - Para quem não pôde acompanhar, já está disponível no YouTube a íntegra da nossa Live de hoje, 06/06/2019:
#
#  Também tratamos da modernização do Mercosul e avançamos nas negociações com outros parceiros, em especial a UE. Estamos empenhados em fazer com que nossa relação seja fonte de prosperidade. Afirmamos, ainda, nossa disposição em seguir defendendo a democracia em nosso continente.
#
#  Nas reuniões de hoje, o presidente @mauriciomacri e eu definimos ações concretas para aprofundar a parceria Brasil-Argentina em áreas de grande importância: comércio e investimentos, segurança pública, infraestrutura, ciência e tecnologia, cooperação nuclear, energia e mineração.
#
#  Cerimônia de Oferenda Floral - Praça San Martín - Buenos Aires/Argentina. 🇧🇷🇦🇷
#
#  - Visitando @neymarjr no Hospital Home em Brasília. Desejo uma boa e rápida recuperação!
#
#  - A PRIMEIRA MISSÃO DO MEU GOVERNO É NÃO ATRAPALHAR QUEM QUER PRODUZIR! 🇧🇷
#
#  O Ministério do Meio Ambiente deverá priorizar destinação de recursos da conversão de multas ambientais do IBAMA até o montante de R$ 100 milhões para o projeto. Estamos mostrando que desenvolvimento econômico e preservação do meio ambiente podem andar lado a lado. 👍🇧🇷
#
#  Hoje, Dia Mundial do Meio Ambiente, participamos do lançamento do Projeto Juntos pelo Araguaia, em Aragarças-GO. Em conjunto com os governadores de Goiás e Mato Grosso, Ministros e secretários estaduais, assinamos acordos para Revitalização da Bacia Hidrográfica do Rio Araguaia.
#
#  OBRIGADO GOIÁS! 🇧🇷🇧🇷🇧🇷
#
#  Presidente Jair Bolsonaro no Programa do Ratinho - 04/06/2019:
#
#  - Correção: o momento em questão ocorreu na cidade de Barra do Garças/MT, na divisa com Aragarças/GO. Obrigado pela compreensão!👍
#
#  - Aragarças/Goiás. MUITO OBRIGADO!
#
#  @dougprs Um beijo para a pequena Laura Danielle!
#
#  RT @MinEconomia: Paulo Guedes diz que equipe econômica tem medidas prontas para retomar o crescimento. Após a aprovação da #novaprevidência…
#
#  MAIS OBRAS RETOMADAS 🇧🇷 - Exército assume obras na BR 116, trecho Guaíba/Tapes, no Rio Grande do Sul. Mesmo com pouco, o Brasil está buscando cumprir com todos os seus compromissos. O trabalho não pode parar!
#
#  Leilão inédito de energia limpa dará auto-suficiência a Roraima até o final de 2020. O Ministro de Minas e Energia, almirante Bento, também anuncia a construção do Linhão Manaus/Boa Vista ainda no corrente ano. 👍
#
#  Em maio, entregamos mais um serviço digital: o cidadão que não concorda com a resposta do INSS pode recorrer direto pela internet. Vamos economizar cerca de R$ 72 milhões ao ano! É só usar o "Meu INSS":
#
#  Com a transformação digital medidas simples fazem a diferença. O cidadão pede a cópia do seu processo e a revisão do seu benefício do INSS pela internet e não precisa ir a uma agência. Medida que vai gerar uma economia de cerca de R$ 72 milhões por ano!
#
#  Estamos firmes na meta de transformar o Brasil numa Nação Digital! Diversos serviços do Governo Federal podem ser acessados pelo cidadão com o mesmo login. Entre os serviços estão os do INSS e o alistamento militar.
#
#  Pela manhã fomos ao Congresso Nacional entregar o Projeto de Lei que estende o prazo de validade da CNH de 5 p/ 10 anos, amplia a pontuação de 20 p/ 40, e libera exames de saúde via SUS e convênios. Governo e Congresso comprometidos nesta pauta, que melhora a vida do brasileiro.
#
#  - Hoje, terça-feira, às 22:15, Ratinho entrevista Jair Bolsonaro no SBT.
#
#  Bom dia, Brasil! Terça, 04 de Junho. Palácio da Alvorada. 🇧🇷👆
#
#  RT @SF_Moro: Brasil e Paraguai atuando juntos para erradicar hectares e mais hectares de plantações de maconha na fronteira e assim descapi…
#
#  GRANDE DIA 👍🇧🇷
#
#  MP 871 APROVADA! Parabéns a todos os parlamentares que se empenharam na aprovação da Medida Provisória que combate fraudes no INSS e que gerará ao país economia de 100 bilhões em 10 anos, em especial o dep @PauloMartins10-PR, relator da proposta. O Brasil avança mais uma vez! 🇧🇷
#
#  Concluo que sem o Foro de São Paulo, o país comunista já teria entrado em colapso há muito tempo.  "O socialismo dura até acabar o dinheiro dos outros." Margaret Thatcher.
#
#  Desde o fim de 2018 a escassez de comida leva a longas filas e desespero em Cuba. A Venezuela, em crise, diminuiu sua oferta de petróleo, que era em parte revendido pela ditadura cubana e, após minha eleição, o Brasil deixou de enviar cerca de R$ 1 bilhão/ano via Mais Médicos.
#
#  @djmaspfc 👍
#
#  @dudubarros_10 👍
#
#  - Hoje deve ser votada no Senado a MP 871, que combate as fraudes no INSS, e nós esperamos por sua aprovação, pelo bem do Brasil e dos brasileiros. Caso aprovada, a ação deve gerar uma economia de R$ 100 bilhões em 10 anos, fundamental para seguirmos crescendo. Vamos!
#
#  - Nesse domingo duas crianças me pediram para conhecer o Alvorada, minha residência até 2022. Autorizado pelos pais, atendi ao pedido com maior satisfação. Confesso que ganhei o dia. Uma boa semana a todos!
#
#  - Fiscalização do TCU aponta 52.600 indícios de irregularidades em folhas de pagamentos de servidores do Executivo, Legislativo e Judiciário. Somente em 17.168 desses indícios as irregularidades chegam a R$ 1,6 bilhão em 2018.
#
#  Nessa semana apresentarei projeto de lei para: 1 - Passar de 5 para 10 anos a validade da Carteira de Habilitação; 2 - Passar de 20 para 40 pontos o limite para perder a CNH. Comente:
#
#  - Nesse domingo o Ministro Marcos Pontes parte para a Guiana Francesa onde visitará o centro de lançamento de Kourou. Acompanhado de deputados e senadores, observará os benefícios e a importância desse seleto mercado espacial. Boa viagem e boa sorte para todos!
#
#  Tales Volpi, conhecido como Mc Reaça, nos deixou no dia de ontem. Tinha o sonho de mudar o país e apostou em meu nome por meio de seu grande talento. Será lembrado pelo dom, pela humildade e por seu amor pelo Brasil. Que Deus o conforte juntamente com seus familiares e amigos.
#
#  - Não existe democracia sem liberdade de expressão. Jamais exigirei demissão de jornalista por críticas feitas contra minha pessoa. Sou alvo de coisas bem piores há décadas. Confio na capacidade das pessoas de discernir o bom do mau jornalismo e tirar suas próprias conclusões.
#
#  O Brasil de todas as religiões sabe que a liberdade é o bem maior de um povo. Brasileiro, olhe o que Israel não tem e o que eles são. Veja o que nós no Brasil temos, e o que não somos. Juntos, com fé, muito trabalho e oração, colocaremos nossa Pátria no local destaque que merece.
#
#  "O Estado é laico, mas eu sou cristão. Não está na hora de o Supremo ter um ministro evangélico?"
#
#  - A Petrobrás informa a redução de 6,0% no preço do DIESEL e 7,2% no preço da GASOLINA. Boa noite a todos!
#
#  👍🇧🇷
#
#  Pela manhã cumprimos agenda em Goiânia-GO. Pausa para almoço ao lado do Governador Ronaldo Caiado, do Min. da Infraestrutura, Tarcisio Gomes de Freitas, do Porta-Voz da presidência, Rêgo Barros, e colegas caminhoneiros, trabalhadores fundamentais para o funcionamento do Brasil.
#
#  - Agradeço a todos que ficaram acordados até agora para nos prestigiar. Tenham um excelente restante de noite!
#
#  DAQUI A POUCO, APÓS A PRAÇA É NOSSA, NO SBT #BolsonaroNoTheNoite
#
#  👍
#
#  - Boa noite a todos e obrigado pelo apoio de sempre! BRASIL ACIMA DE TUDO! DEUS ACIMA DE TODOS! 🇧🇷👍🏻
#
#  LIVE DE 30 DE MAIO: Daqui a pouco, às 19h, entraremos ao vivo pelo Facebook para mais uma Live onde abordamos temas importantes da semana. Até já! 👍
#
#  RT @BolsonaroSP: A sempre atual Margaret Thatcher, a Dama de Ferro. Qual é o papel do Estado? Quanto o Estado pode arrecadar de impostos do…

# %%
#Chama a função passando como parâmetro o usuário e se a pesquisa vai incluir os Retweets ou não
tweets_lula = extrair_tweets('LulaOficial', True)
for i in tweets_lula:
    print('\n', i)
# Out:
#  Novo juiz da Lava Jato descumpre ordem do Supremo Tribunal Federal
#
#  Ontem, na apresentação da Orquestra Sinfônica da Bahia com a banda Baiana System, o coro foi um só: #LulaLivre  Vídeo: Renato Nunes
#
#  RT @gleisi: Na Câmara, Moro fugiu de diversas perguntas e mentiu sobre fatos conhecidos, como o grampo ilegal de Lula e Dilma #MoroCorrupto…
#
#  RT @PTnaCamara: #VazaJato | O deputado @RFalcao13 (PT-SP) fala direto e reto a verdade para #MoroCorrupto: "O senhor corrompeu a Justiça br…
#
#  RT @PTnaCamara: #VazaJato | O deputado José @guimaraes13PT (PT-CE) reforça desafio do @deputadofederal Paulo Pimenta (PT-RS) a Moro para qu…
#
#  RT @PTnaCamara: #VazaJato | A deputada @MariadoRosario (PT-RS) põe Moro contra a parede: "O senhor acha natural que o procurador Dallagnol…
#
#  RT @PTnaCamara: #VazaJato | O deputado @RogerioCorreia_ (PT-MG) recorda que outros meios de comunicação confirmaram diálogos revelados pelo…
#
#  RT @PTnaCamara: #VazaJato|O deputado @AlencarBraga13 (PT-SP) cobra o fim da hipocrisia de #MoroCorrupto: "Juiz ñ pode combinar o jogo e sug…
#
#  RT @PTnaCamara: #VazaJato|A deputada @natbonavides (PT-RN) aponta as contradições na defesa de #MoroCorrupto: "É como se tivesse 2 Moros: u…
#
#  RT @PTnaCamara: #VazaJato | O deputado @JoseildoRamos (PT-BA) relaciona os crimes de #MoroCorrupto como juiz parcial da Lava Jato e pergunt…
#
#  RT @DeputadoFederal: MORO NÃO ACEITA DESAFIO DE ABRIR O SIGILO  Falei na audiência que abro mão do meu sigilo se o ministro Moro abrir mão…
#
#  RT @MarceloFreixo: O @SF_Moro está usando o ministério da Justiça e a Polícia Federal pra atacar a liberdade de imprensa. Numa tentativa de…
#
#  RT @MarceloFreixo: O ministro @SF_Moro precisa se decidir... Primeiro diz que não reconhece os diálogos, pra logo depois fazer uma longa de…
#
#  RT @MarceloFreixo: #AOVIVO da Câmara: ministro @SF_Moro enrola e não responde nossas perguntas.
#
#  RT @gleisi: Mesmo c/ as evidências, Moro segue c/ mantras: tenta incriminar jornalista q o expôs e usa a Lava Jato p/ dizer q só agiu contr…
#
#  RT @gleisi: Foi noticiado que a Polícia Federal quer investigar as atividades financeiras de @ggreenwald. A PF é subordinada a Moro, q vem…
#
#  A parcialidade de Sérgio Moro é notícia no mundo inteiro.   Do jornal britânico @Independent
#
#  RT @DeputadoFederal: Moro fala sobre os crimes da Vaza Jato
#
#  As mentiras de Léo Pinheiro, idealizadas pela Força-Tarefa da Lava Jato, pavimentaram o caminho para colocar na prisão um homem inocente. Compartilhe a verdade. #LulaLivreJá
#
#  #LulaLivre
#
#  No TRF4, o advogado Cristiano Zanin já havia apontado as incoerências de Leo Pinheiro. As denúncias agora reveladas pela Folha comprovam que o executivo da OAS foi pressionado pela Lava Jato a mudar sua posição para fabricar uma versão contra Lula e obter redução de pena.
#
#  A sentença de Moro para condenar Lula não deixa dúvida de que se amparou unicamente no depoimento de Leo Pinheiro. Trata-se de material que por si só não deveria ter qualquer valor probatório, uma vez que Leo Pinheiro falou na condição de corréu.
#
#  #LulaLivreJá
#
#  Para lembrar.  Já são 449 dias de uma prisão política. #LulaLivreJÁ
#
#  Em Belo Horizonte #LulaLivreDomingoSDV
#
#  RT @ggreenwald: E para quem perdeu ontem de noite: o maior jornal de Brasília, @correio, destruiu a única tática de Moro: cínica e falsamen…
#
#  RT @ggreenwald: Na @Folha, leia as mensagens entre procuradores usados. Lembra, nas palavras da @Folha, que eles "indicam troca de colabora…
#
#  RT @ggreenwald: Essa é a chave para esse escândalo: Moro e LJ usaram meios corruptos para "combater a corrupção" - inclusive colaborando ju…
#
#  RT @ggreenwald: Um de nossos primeiros artigos revelou que a LJ sabia que eles não poderiam ligar o caso de Lula à Petrobras, o que signifi…
#
#  Leo Pinheiro, que ao longo do processo nunca havia incriminado Lula, foi pressionado e repentinamente alterou sua posição anterior em troca de benefícios negociados com procuradores de Curitiba, obtendo a redução substancial de sua pena.
#
#  Moro é mentiroso. Dallagnol é mentiroso.  E a Globo está tentando salvar os dois. #LulaLivreDomingoSDV
#
#  Lulaço ontem em Brasília.  Pelo fim da farsa judicial contra Lula. #LulaLivredomingoSDV
#
#  Morobol #LulaLivre
#
#  RT @TheInterceptBr: Por que o @TheInterceptBr está publicando as matérias da #VazaJato aos poucos?
#
#  RT @grazianodasilva: Ao fim de minha última Conferência da @FAO como Diretor-Geral, não pude deixar de homenagear o grande inspirador de me…
#
#  Relembrar é viver. #timelula
#
#  RT @costa_rui: O amor vai vencer o ódio.  Está escrito em um quadro na parede do presidente @LulaOficial e em nossos corações. O Brasil é m…
#
#
#
#  🚨 AO VIVO: Governadores visitam Lula: acompanhe o relato de Rui Costa, da Bahia, e Wellignton Dias, do Piauí, sobre encontro com o ex-presidente na prisão #LulaLivreJá
#
#  RT @sejademocracia: Em 27 de junho de 2005, o presidente @LulaOficial sanciona a Lei nº 11.126/2005, que dispõe sobre o direito da pessoa c…
#
#  Lava Jato quer “bloquear” dinheiro que Lula não tem.
#
#  #TBT Marcha das Margaridas, com um presidente que fortalece a luta das mulheres do campo, da floresta e das águas  📷: Ricardo Stuckert #MarchadasMargaridas #RumoaMarchadasMargaridas2019
#
#  Os governadores @wdiaspi, do Piauí, e @costa_rui, da Bahia, fazem visita de solidariedade a Lula.
#
#  Nota dos advogados do ex-presidente Lula
#
#  #FREELULA   A congressista democrata norte-americana @AOC em defesa da liberdade de Lula.
#
#  #LulaLivreJá
#
#  “O Partido dos Trabalhadores, em conjunto com todas as forças democráticas e populares, continuará cobrando do STF a devida resposta às graves denúncias da parcialidade, ilegalidade e arbitrariedade no processo contra Lula”
#
#  RT @lapsofreudiano: Saudade do tempo que os integrantes da comitiva presidencial levavam frango pra botar no cofre.
#
#  RT @ptbrasil: A presença de Glenn Greenwald na Câmara dos Deputados nesta terça-feira (25) transformou o que era para ser uma audiência púb…
#
#  RT @Haddad_Fernando: Fernando Haddad Flávio Dino Guilherme Boulos Ricardo Coutinho Roberto Requião Sônia Guajajara  Opinião: A corrupção da…
#
#  RT @gleisi: Essa decisão não fez Justiça, pq Lula continuará esperando ilegalmente preso. Mas Sérgio Moro permanece no banco dos réus e são…
#
#  RT @folha: Em Paris, Chico Buarque e artistas brasileiros e franceses leem cartas mandadas a Lula na prisão
#
#  Emídio de Souza e Luiz Eduardo Greenhalgh, advogados de Lula, relatam visita ao ex-presidente #LulaLivreUrgente
#
#  RT @gleisi: Com a decisão do STF de julgar o Habeas Corpus de Lula hoje, esperamos por Justiça! #LulaLivre
#
#  RT @senadorhumberto: A defesa de @LulaOficial formulou, ao final, o seguinte pedido: se não for possível concluir o julgamento das ações ho…
#
#  RT @erikakokay: O @ggreenwald diz que ao receber o material da Vaza Jato ficou chocado com o que viu. "Em nenhum país democrático do mundo…
#
#  RT @GuilhermeBoulos: Quem defende que todos têm direito a uma justiça imparcial e que juízes ou procuradores não estão acima da lei, defend…
#
#  RT @GuilhermeBoulos: O Brasil assiste Glenn Greenwald dar depoimento na Câmara dos Deputados sobre a VazaJato e aguarda o STF julgar o pedi…
#
#  #LulaLivreUrgente
#
#  RT @DeputadoFederal: O ministro Gilmar Mendes pediu liberdade imediata para Lula até que seja julgado definitivamente o habeas corpus.  #Lu…
#
#  RT @senadorhumberto: Veja a defesa do advogado de @LulaOficial, @czmartins, no plenário da Segunda Turma do STF. A sessão não está sendo tr…
#
#  RT @inst_lula: A cada novo vazamento a indignação só aumenta. Cadê a prova contra Lula? #LulaLivreUrgente
#
#  RT @levantepopular: Em frente ao TRF4! #LulaLivreUrgente
#
#  RT @DeputadoFederal: Estamos no STF aguardando a reunião da turma onde o pedido de habeas corpus do presidente @LulaOficial está pendente.…
#
#  Lula é um preso político e deve ser libertado. Por @bbimbi, no @nytimes #LulaLivreUrgente
#
#  RT @DeputadoFederal: Também hoje em Brasília, ativistas estenderam faixas numa das principais vias do DF para denunciar a prisão política d…
#
#  Bom dia com #LulaLivreJÁ
#
#  RT @JohnMAckerman: Un honor participar en el desplegado publicado hoy en París por @lemondefr de destacados juristas del mundo a favor de l…
#
#  RT @LuisCValois: A questão não é de violação da paridade de armas. O juiz conversava "carinhosamente" com uma parte e grampeava o advogado…
#
#  Já são quase 15 meses de uma prisão injusta e ilegal. #LulaPresoPolítico
#
#  RT @DeputadoFederal: Já estava claro que @LulaOficial passou por um tribunal de exceção controlado pelo juiz da #LavaJato e agora as provas…
#
#  #LulaPresoPolítico
#
#  #LulaPresoPolítico
#
#  #LulaPresoPolítico
#
#  #LulaPresoPolítico
#
#  #LulaPresoPolítico
#
#  #LulaPresoPolítico
#
#  #LulaPresoPolítico
#
#  Já são 15 meses de uma prisão política. Lula tem direito a um julgamento justo. #LulaLivreJÁ
#
#  Quero ser julgado pelas leis do meu país, e não pelas manchetes dos jornais. A pergunta que faço todos os dias aqui onde estou é uma só: por que tanto medo da verdade? A resposta não interessa apenas a mim, mas a todos que esperam por Justiça.
#
#  Tudo que espero é que a justiça finalmente seja feita. Quero é ter direito a um julgamento justo, por um juiz imparcial, para poder demonstrar com fatos que sou inocente. Quero ser julgado dentro do processo legal, com base em provas, e não em convicções.
#
#  Tentam confundir dizendo que meu caso só pode ser julgado depois de uma investigação sobre as mensagens entre Moro e os procuradores. Mas entramos com a ação em novembro, muito antes dessas revelações. Apresentamos provas suficientes de que o juiz é suspeito e não foi imparcial.
#
#  Alguns dizem que ao anular meu processo estarão anulando todas as decisões da Lava Jato, o que é uma grande mentira pois na Justiça cada caso é um caso.
#
#  Meus advogados recorreram ao STF, para que eu tenha finalmente um processo e um julgamento justos, o que nunca tive nas mãos do Moro. Muita gente poderosa, daqui e de outros países, quer impedir essa decisão, ou continuar adiando, que dá no mesmo para quem está preso injustamente
#
#  RT @gleisi: Lula disse ao advogado Zanin q quer seu julgamento já, conforme pauta do STF. A justiça ñ pode ficar suspensa, seja qual for re…
#
#  Leia a íntegra da nova carta de Lula:
#
#  Lula escancara a verdade sobre Moro e Dallagnol. Assista, compartilhe e espalhe a realidade sobre a prisão de Lula. #LulaLivreJÁ  Vídeo: Ricardo Stuckert
#
#  "A independência da magistratura é uma responsabilidade imposta sobre cada juiz e se afirma em decisões honestas, imparciais baseadas no direito e nas provas", indicou o grupo em uma declaração lida na ONU. #LulaLivreJÁ
#
#  “O Supremo deve libertar Lula” dizem juristas europeus #LibertemLula #anulatríplex #LulaLivreSegundaSDV
#
#  Juristas europeus assinam manifesto pela liberdade de Lula e contra a farsa que foi seu julgamento por Moro. #LulaLivreSegundaSDV  #anulatríplex
#
#  Porque o julgamento de Lula no caso do tríplex deve ser anulado, por Cristiano Zanin Martins e Valeska Teixeira. #TimeLula #LulaLivre
#
#  Em novembro de 2017, o próprio Moro dizia reconhecer um dos argumentos do HC de Lula que será julgado no Supremo na terça-feira. O de que ele assumir um cargo político colocaria em dúvida o trabalho dele como o juiz. Ou ele foi hackeado? #TimeLula #LulaLivre
#
#  O amor sempre vence.   Foto: Cosmo Silva
#
#  RT @czmartins: 1/ Agradeço a referência feita a mim por @merval_merval em sua coluna de hoje, mas, diferentemente do que ali constou, não "…
#
#  Moro mentiu no Senado e Dallagnol em nota divulgada para a imprensa. #TimeLula #LulaLivre #anulaTriplex
#
#  Não faça como alguns que opinam sobre o HC de Lula sem ler. Veja a íntegra do documento apresentando 1º de novembro de 2018, muito antes da #vazajato Saiba porque o funcionário de Bolsonaro jamais poderia ter julgado Lula. #timeLula #LulaLivre
#
#  E o Queiroz?
#
#  A análise do juiz em que Moro se espelhou.
#
#  RT @ocolunista_: THREAD PARA EXPOR O MPF  Já viram a nota que o procuradorzinho @deltanmd publicou sobre o vazamento do @reinaldoazevedo co…
#
#  #LibertemLuls
#
#
#
#  “Novos vazamentos apontam que o ex-juiz Sérgio Moro interferiu na composição da bancada acusatória de ação do triplex contra Lula e mentiu quando questionado sobre isso na CCJ”   #MoroMentiu
#
#  Moro mente, mas a verdade vencerá. #MoroMentiu
#
#  Carta de Lula aos companheiros de luta do @mtst.
#
#  RT @czmartins: Nesse vídeo é possível verificar, exemplificativamente, a delimitação temporal que foi artificialmente estabelecida na "oper…
#
#  Carta do presidente Lula ao amigo Chico Buarque.
#
#  AO VIVO: @Gleisi Hoffmann e @GuilhermeBoulos relatam encontro com Lula na prisão; saiba como foi
#
#  Nos Estados Unidos, ninguém acha normal juiz aconselhando procurador. #timeLula #LulaLivre
#
#  RT @FreeLulaBrasil: #VazaJato no @dwnews | Alemanha Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @SZ | Alemanha Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @Tagesspiegel | Alemanha Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @RadioCaput | Argentina Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @pagina12 | Argentina Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @EnOrsai | Argentina Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @clarincom | Argentina Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @adnradiochile | Chile Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @El_Ciudadano | Chile Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @RPPNoticias | Peru Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @minutounocom Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @nacioncl | Chile Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @ABCDigital | Paraguai Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @eldiario_net | Bolívia Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @LaVanguardia | Espanha Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @el_pais | Espanha Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @elmundoes | Espanha Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @publico_es | Espanha Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @eldiarioes | Espanha Leia a matéria completa:
#
#  RT @FreeLulaBrasil: #VazaJato no @nytimes | Estados Unidos Leia a matéria completa:
#
#  RT @FreeLulaBrasil: Apesar de ter recebido uma cobertura amena pela @RedeGlobo, o escândalo, conhecido como #VazaJato, foi tratado com a se…
#
#  RT @FreeLulaBrasil: Para tanto, os responsáveis pela Operação Lava Jato recorreram a condutas ilícitas, antiéticas e transgressões diversas…
#
#  RT @FreeLulaBrasil: Escritas a partir de material obtido por fonte anônima, as reportagens fornecem evidência material da trama entre os pr…
#
#  RT @FreeLulaBrasil: [Thread | Fio] #VazaJato na Imprensa Internacional   Em meados de junho, o @TheInterceptBr iniciou a publicação de uma…
#
#  “Moro, peça desculpas ao povo brasileiro, pelos milhões de votos que o senhor cassou de quem queria outro presidente para o Brasil, que está preso em Curitiba e não esse que está aí.”
#
#  RT @DCM_online: Plateia pede Lula Livre em show de Elza Soares; assista ao vídeo
#
#  Na pauta do encontro, as recentes denúncias da cooperação do ex-juiz Sérgio Moro com procuradores da operação Lava Jato. @gleisi @GuilhermeBoulos #LulaLivreJá
#
#  RT @TheInterceptBr: 'Melindra alguém cujo apoio é importante'. O ex-juiz Sergio Moro discordou de investigações sobre o ex-presidente Ferna…
#
#  RT @inst_lula: 📍 O Instituto Lula espera que as novas revelações do @TheInterceptBr restabeleçam a verdade nos processos e anulem as conden…
#
#  RT @GuilhermeBoulos: A mensagem de Moro blindando FHC mostra que na Lava Jato a lei era para todos, menos para os amigos do juiz. #MoroJuiz…
#
#  “Diante dessas revelações, espera-se que as evidências sejam usadas para anular as injustas condenações contra o Instituto e contra o ex-presidente Lula.”
#
#  RT @gleisi: Que moral tem FHC para pressionar STF a manter Lula preso? Moro jogou pra debaixo do tapete graves denúncias contra ele  pra "n…
#
#  RT @ggreenwald: EXCLUSIVO e NOVO Lava Jato fingiu investigar FHC apenas para criar percepção pública de ‘imparcialidade’, mas Moro repreend…
#
#
#
#  RT @NaomiAKlein: This explosive investigation shows that Brazil's elections were rigged - there was a conspiracy to exclude the leading can…
#
#  A verdade já é livre. Falta o Lula. #LulaLivre #FreeLula #LulaLibre
#
#  RT @PTnaCamara: Paulo Pimenta denuncia no Parlamento Europeu participação secreta e ilegal dos EUA na Lava Jato #VazaJato
#
#  RT @LaurenceCohen94: Depuis le 7 avril 2018, @LulaOficial  est emprisonné sans preuves!   La caravane #LulaLivre va plaider en sa faveur au…
#
#  Londres, hoje, Barbican Center #timeLula
#
#  RT @ggreenwald: Exclusive: Brazilian judge in Car Wash corruption case - now Bolsonaro's Justice Minister Sergio Moro - mocked Lula’s defen…
#
#  A verdade vencerá a mentira.
#
#  RT @czmartins: Depois de tudo que apresentamos desde 2016 – no Brasil e na ONU - alguém genuinamente pode ter dúvida de que havia uma consp…
#
#  RT @DeputadoFederal: Manchetes do mundo todo mostram que só a Globo se recusa a fazer jornalismo sobre o escândalo #VazaJato   Parabéns @Th…
#
#  RT @dantherriault: This is actual journalism. Proving through data that those in power in Brazil corrupted the courts to be used against po…
#
#  Traduzindo o título do inglês: Lula é inocente. O libertem agora. #TimeLula
#
#
#
#  RT @inst_lula: “Eu vou chegar em casa amanhã e vou almoçar com 8 netos e uma bisneta de 6 meses. Eu posso olhar na cara dos meus filhos e d…
#
#  Nota de condolências pela perda do jornalista Clóvis Rossi.
#
#  RT @ComiteLula: #GreveGeral "A sociedade brasileira tem o direito de se indignar", diz @LulaOficial
#
#  O ex-presidente falou pela 1ª vez sobre os escândalos denunciados pelo @TheInterceptBr sobre a cooperação do ex-juiz Sérgio Moro na condução da operação Lava Jato. “Se tivessem nos levado a sério, não estariam surpresos agora”, disse à @redeTVT.
#
#  RT @MonederoJC: El Gobierno de Bolsonaro tiene en la cárcel al expresidente @LulaOficial por una decisión ajena al Estado de derecho. Es de…
#
#  LULA AO VIVO: assista a entrevista pela @redeTVT #LulaNaTVT
#
#  A lei é para todos? Ótimo. Mas eu não posso prender o meu vizinho porque não gosto dele. #LulaNaTVT
#
#  Não acharam uma calota de um carro roubado por mim e estou aqui enclausurado há mais de um ano. Não posso aceitar isso. #LulaNaTVT
#
#  O Moro quando a mosca azul da Rede Globo pousou na testa dele ele virou serviçal da Globo. Por isso a loucura deles de desmoralizar o @ggreenwald. A Globo está com medo de ser citada. #LulaNaTVT
#
#  Lula ao vivo na @redeTVT:  #LulaNaTVT
#
#  A única coisa que eu espero é que se faça justiça. Eu tô pedindo a Deus que alguma instância leia meu inquérito. #LulaNaTVT
#
#  Juca Kfouri (@BlogdoJuca) e José Trajano (@ultrajano) entrevistam Lula na prisão. Assista ao vivo:  #LulaNaTVT
#
#  Essa facada foi muito estranha. Uma facada que não teve sangue, que os seguranças ao invés de protegerem o Bolsonaro protegeram o esfaqueador... #LulaNaTVT
#
#  O STF tem que ter coragem de assumir o papel de guardião da Constituição. Não pode um juiz de primeira instância mandar em todas as outras instâncias. #LulaNaTVT
#
#  Eu tive 87 testemunhas de defesa e o Dallagnol não apareceu em uma audiência. Eu nem precisava de advogado, porque meu processo é 100% pautado por decisão política. #LulaNaTVT
#
#  Eu sei o que as pessoas passaram pra me defender. Vocês não sabem o carinho que tenho por essas pessoas que estão aqui na Vigília Lula Livre. Essa molecada do Moro conseguiu colocar pânico na sociedade. #LulaNaTVT
#
#  VOLTAMOS AO VIVO - Lula fala pela primeira vez sobre as denúncias do Intercept #LulaNaTVT
#
#  Eu tive uma boa relação com os militares. Se você procurar qualquer general que tenha orgulho desse país vai dizer. Agora, tem general que aceita se subordinar à bandeira norte-americana. As Forças Armadas existem pra defender a soberania nacional. #LulaNaTVT
#
#  O Mia Couto diz que quando a sociedade está com medo ela se aproxima do monstro. Foi o que aconteceu com o Bolsonaro. Ele é resultado do pânico que os meios de comunicação criaram no Brasil sobre a política. #LulaNaTVT
#
#  A Globo deu mais tempo pro Dallagnol se justificar do que pra protagonista da novela das nove, a tal da Dona do Pedaço. Eu gostaria de sentar com o William Bonner, que faz seis anos que só sabe falar mal de mim. Fala mais meu nome que do filho dele. #LulaNaTVT
#
#  Eles construíram um processo de mentira. Eu disse ao Moro no meu primeiro depoimento que a desgraça de quem conta a primeira mentira é que passa a vida inteira mentindo pra justificar a primeira. #LulaNaTVT
#
#  AO VIVO: Lula fala pela primeira vez sobre as denúncias do @TheInterceptBr #LulaNaTVT
#
#  AO VIVO: Entrevista de Lula na Rede TVT #LulaNaTVT
#
#  A verdade pode ficar doente, mas ela não morre. O falso moralismo deles levou o Brasil à bancarrota. #LulaNaTVT
#
#  Instituições poderosas não podem ser administradas por moleques irresponsáveis. Quantas empresas quebraram por causa da brincadeira deles? Eles poderiam combater a corrupção, inclusive prender empresários, sem quebrar as empresas. #LulaNaTVT
#
#  A máscara vai cair. Estou mais tranquilo que o Moro e o Dallagnol. Eles sabem que estão mentindo. Eu espero que se faça justiça nesse país. #LulaNaTVT
#
#  O Moro estava condenado a me condenar porque a mentira que eles contaram já estava muito grande. Mas Deus escreve certo por linhas tortas. A imprensa não acreditou quando falávamos o que o @TheInterceptBr está mostrando agora. #LulaNaTVT
#
#  🚨🎥 AO VIVO: Entrevista de Lula na Rede TVT #LulaNaTVT
#
#  Hoje, às 20h, na @RedeTVT. #LulaNaTVT
#
#
#
#  RT @inst_lula: "Lawfare" é o termo usado para descrever a trama contra Lula: o poder judiciário vira arma de guerra, ao invés de instrument…
#
#  RT @teleSURtv: La justicia de Brasil debería liberar a @LulaOficial y anular su condena de cárcel, demandó el aspirante demócrata a la pres…
#
#  Hoje. Não perca a entrevista inédita de Lula.
#
#  Até quando? #LibertemLula
#
#  RT @redeTVT: Nesta quinta-feira, tem entrevista inédita com o ex-presidente Lula aqui na TVT!  Não perca!   Às 20h na TV e no nosso canal d…
#
#  RT @Haddad_Fernando: Moro deveria ter sido afastado da LavaJato quando quebrou ilegalmente o sigilo telefônico de um chefe de Estado. Crime…
#
#  RT @Haddad_Fernando: Diálogo de Moro é ilegal, imoral e vetado no mundo todo, dizem juristas  via @UOLNoticias @UOL
#
#  RT @TheInterceptBr: Decidimos publicar mais trechos de conversas entre @SF_Moro e @deltanmd. Leia aqui.  #VazaJato #…
#
#  RT @ggreenwald: Todos os documentos, chats, áudios, vídeos, etc., são autênticos. Ninguém pode parar a reportagem. A verdade sobre Moro, De…
#
#  RT @ggreenwald: No início da reportagem de Snowden, o governo dos EUA não sabia que provas tínhamos, então começaram a mentir e, toda vez q…
#
#  RT @radiobandnewsfm: EXCLUSIVO: O editor-executivo do Intercept Brasil, @demori, revela uma nova conversa envolvendo @SF_Moro e o procurado…
#
#  RT @radiobandnewsfm: "Imagina se as conversas (do @SF_Moro), em vez do @deltanmd, fossem com o Zanin, advogado do @LulaOficial. O advogado…
#
#  RT @redeTVT: Nesta quinta-feira, tem entrevista inédita com o ex-presidente @LulaOficial aqui na TVT!  Às 20h na TV e no nosso canal do You…
#
#  Amanhã, na @RedeTVT. O que Lula tem a dizer. Às 20h, não perca. #LulaNaTVT
#
#  Em tempo, Feliz Dia dos Namorados...  #LulaLivreJá  Foto: Ricardo Stuckert
#
#  RT @theintercept: Fromer Brazilian President Luiz Inácio Lula da Silva should be released from prison and his conviction should be annulled…

# %% [markdown]
# Agora que já temos um meio de extrair os Tweets e Retweets, podemos plotar mais um gráfico de barras para análisar o resultado.
#
# Abaixo, chamamos a função `extrair_tweets()` passando como parâmetro o nome do usuário e a opção *booleano False*, o que indica que o retorno a função será apenas dos Tweets feitos pelo próprio usuário.
#
# Já para calcular a quantidade de Retweets, basta fazer 200 (número máximo disponível para recuperação via `user_timeline()`) e subtrair a quantidade de Tweets feita pelo usuário.

# %%
#Verifica quantos Tweets são extraidos
tweet_bolsonaro = len(extrair_tweets('jairbolsonaro', False))
tweet_lula = len(extrair_tweets('LulaOficial', False))

#Criando um DataFrame para uso do gráfico
df = pd.DataFrame({'Tweets': [tweet_bolsonaro, tweet_lula], 'Retweets': [200-tweet_bolsonaro, 200-tweet_lula]}, 
                 index=['Bolsonaro', 'Lula'])

#Plotando o gráfico de barras
df.plot.bar(rot=0, stacked=True, grid=True, title='Relação de Tweets e Retweets', figsize=(10, 5))

# %% [markdown]
# ---
# No gráfico mostrado acima, é possível notar mais uma diferença grande entre os dois perfis, com a extração dos últimos 200 Tweets e Retweets, é possível observar que o perfil do atual presidente utiliza bem menos da opção de Retweet, enquanto ao perfil do ex-presidente que tem o uso contrario.
#
# ## 4. Filtrar termos em Tweets e Retweets
#
# Agora já podemos procurar por termos/palavras específicas nos Tweets que foram extraídos anteriormente, abaixo na função `filtrar_tweets_termos()` é possível utilizar de uma lista de palavras para serem pesquisadas nos tweets.
#
# A função apresenta três parâmetros, são eles:
# * `lista_tweets_pesquisa` que é onde os Tweets extraídos foram armazenados
# * `termo_pesquisa` que é a lista de palavras que seja pesquisada
# * `quant_termos` que é uma lista para guarda quantas vezes determinada palavra foi encontrada
#
# Inicialmente preenchemos a quantidade de vezes que os termos são encontrados, ou seja, iniciam com 0, e logo em seguida é feita a busca de cada termo informado na lista nos Tweets e Retweets recuperados, utilizando dois laços para realizar essa pesquisa. O método `search()` é utilizado para pesquisar o termo de forma *case-sensitive*.

# %%
#Verifica a quantidade de Tweets e Retweets dos usuários onde menciona um termo específico
def filtra_tweets_termos(lista_tweets_pesquisa, termo_pesquisa, quant_termos):
    for i in range(len(termo_pesquisa)):
        quant_termos.append(0)
    ii = 0
    for termo in termo_pesquisa:
        termos_encontrador = 0
        for tweet_user in lista_tweets_pesquisa:
            if re.search(termo, tweet_user, re.IGNORECASE):
                termos_encontrador += 1
            quant_termos[ii] = termos_encontrador
        ii += 1
        
#Define quais os termos que serão pesquisados
termo_pesquisa = ['bolsonaro', 'lula', 'pt', 'psl', 'previdência', 'arma']

# %% [markdown]
# Abaixo efetuamos a extração dos tweets recentes dos usuários, declaramos uma lista vazia para guardar a quantidade de vezes que o termo é encontrado nos Tweets e Retweets de cada usuário e chamamos a função `filtra_tweets_termos()`.

# %%
#Extraindo Tweets e Retweets realizando a pesquisa dos termos
tweets_bolsonaro = extrair_tweets('jairbolsonaro', True)
quant_termos_bolsonaro = []
filtra_tweets_termos(tweets_bolsonaro, termo_pesquisa, quant_termos_bolsonaro)

# %%
#Extraindo Tweets e Retweets realizando a pesquisa dos termos
tweets_lula = extrair_tweets('LulaOficial', True)
quant_termos_lula = []
filtra_tweets_termos(tweets_lula, termo_pesquisa, quant_termos_lula)

# %% [markdown]
# Logo após será criado um Data Frame contendo as informações que foram retornadas da função.

# %%
#Criando um DataFrame
df = pd.DataFrame({'Bolsonaro': quant_termos_bolsonaro, 'Lula': quant_termos_lula}, 
                 index=termo_pesquisa)
df
# Out:
#              Bolsonaro  Lula
# bolsonaro           16     5
# lula                 1   133
# pt                   1    24
# psl                  0     0
# previdência          2     0
# arma                 5     3

# %% [markdown]
# ---
# Com o Data Frame criado, podemos assim realizar a plotagem do gráfico para visualizarmos graficamente a quantidade de vezes que determinado termo foi encontrados nos tweets dos dois perfis.

# %%
#Plotando o gráfico de barras
df.plot.bar(rot=0, color=['green','red'], grid=True, title='Relação dos termos pesquisados', figsize=(10, 5))

# %% [markdown]
# ---
# ## 5. Trends Topics
#
# O nascimento das *Trends Topcis* tem basta interação com o momento atual da região/local de onde se está. Por exemplo, durante os jogos da seleção brasileira feminina e masculina, quando os times estão jogando é normal que nome de jogadores que tenham se destacado no jogo apareça nas *Trends Topics* do Twitter.
#
# Diante disto, a análise sobre os tópicos de tendência são mais difíceis, devido sua **alta taxa de volatilidade**, porem é possível verificar quais as *Trends Topics* do momento.
#
# Primeiramente informamos o identificador da região no qual desejamos verificar os tópicos de tendência **(ID do Brasil é 23424768)** e com o método `trends_place()` é retornado um **Objeto Json** contendo algumas informações sobre os tópicos, como desejamos apenas verificar quais são os top 10 tópicos de tendência, carregamos o resultado do método dentro de uma variável e realizamos a pesquisa das *Trends Topics* e utilizamos um laço para localizar os 10 primeiros tópicos de tendência, e por fim, são impressas na tela.

# %%
#Informa o ID do local da pesquisa e captura as tendências do local
codigo_regiao = 23424768 #Código do Brasil
#Coleta as Trends Topics da região solicitada 
def localiza_trends(codigo_regiao):
    top_trends = api.trends_place(codigo_regiao)
    trends = json.loads(json.dumps(top_trends, indent=1))
    max_topic = 0
    top10_trend = []
    #Extrai as Trends
    for trend in trends[0]["trends"]:
        top10_trend.append(trend["name"])
        max_topic += 1
        if max_topic == 10:
            break
    #Imprime os trends topics
    for i in top10_trend:
        print(i)

# %%
#Chama a função para localizar as Trends
localiza_trends(codigo_regiao)
# Out:
# O WhatsApp
# Zuckerberg
# Conmebol
# Instagram e Facebook
# Mark
# #EuBoicoto
# 500 BILHÕES
# Palocci
# #AReformaTeEngana
# #LuteComoUmJornalista

# %% [markdown]
# ---
# No caso abaixo é utilizado o método `trends_closest()` que retorna um **Objeto Json**, nele é informado dados sobre a localidade mais próxima no qual o Twitter ter registros de Trends Topics.
#
# Basta passar como parâmetros do método a latitude e longitude de local, uma das formas mais simples de se obter essa informação é utilizando o [Google Maps](https://www.google.com/maps), logo depois da *url* é possível encontrar essa númeração. Segue uma imagem para exemplo.
#
# ![Imagem Indisponível](attachment:Sem%20t%C3%ADtulo.png)

# %%
#Localiza qual o local mais próximo de topicos de tendência de acordo com a localização atual
teste = api.trends_closest(-7.2419179,-35.8825136)
localidade = list(teste[0].values())
print('A localidade mais próxima que possui tópicos de tendência é', 
      localidade[0], 'que tem o ID:', localidade[5])
# Out:
# A localidade mais próxima que possui tópicos de tendência é Fortaleza que tem o ID: 455830

# %% [markdown]
# ---
# Agora que já possuímos o ID da região mais próxima a nós, podemos verificar se as mesmas *Trends Topics* do Brasil são as mesmas da região de Fortaleza, como foi dito anteriormente, as *Trends Topics* tem uma forte relação com acontecimentos de uma determinada região, seja um fato histórico, uma tragédia, uma novela ou qualquer outro motivo que seja marcante ou de grande importância para a maioria dos usuários da rede social.
#
# Basta chamar novamente a função `localiza_trends()` e passar como parâmetro o ID que nos foi retornado (neste caso o de Fortaleza de ID 455830).

# %%
#Chama a função para localizar as Trends
localiza_trends(455830)
# Out:
# Argentina
# O WhatsApp
# Zuckerberg
# Conmebol
# Instagram e Facebook
# Mark
# #EuBoicoto
# 500 BILHÕES
# Palocci
# #AReformaTeEngana

# %% [markdown]
# ---
# ## 6. Conclusões
#
# Com a elaboração deste projeto, aprendemos a utilizar a biblioteca **Tweepy** para realizar algumas operações essenciais para o objetivo específico do trabalho, como a coleta de Tweets de um perfil específico, a coleta de informações sobre um usuário específico, a forma de organização dos dados do Twitter, as divisões das trends topics por região, a pesquisa de determinados termos dentro de tweets entre outras funcionalidades.
#
# Com a elaboração do projeto acima, foi possível investigar melhor as bibliotecas **Tweepy**, **Re**, **Json**, **Matplotlib**, **Numpy** e **Pandas** que já são bastante conhecidas e vale a pena aprofundar os conhecimentos nelas, pois a possibilidade de utilizarmos em novos projetos é muito grande.
#
# Utilizamos da possibilidades de fazer um estudo comparativo entre dois perfis mas acreditamos que o objetivo geral do trabalho foi alcançado, pois tivemos a ideia de dar uma ampla visão das possibilidade do que se pode fazer com a API do Twitter em suas principais funcionalidades (possibilidades essas que estão fragmentadas por tutoriais na internet, o que dificulta o estudo de quem se interessa no desenvolvimento de pesquisas na área).
#
# ## 7. Referências
#
# **Documentações**
#
# * [Tweepy](http://docs.tweepy.org/en/latest/)<br>
# * [Numpy](https://docs.scipy.org/doc/numpy/dev/)<br>
# * [Pandas](https://pandas.pydata.org/pandas-docs/stable/)<br>
# * [Matplotlib](https://matplotlib.org/3.1.0/contents.html)<br>
# * [Json](https://docs.python.org/3/library/json.html)<br>
# * [Re](https://docs.python.org/3/library/re.html)<br>
# * [Developer Twitter](https://developer.twitter.com/en.html)<br>
